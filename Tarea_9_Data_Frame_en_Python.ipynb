# %% [markdown]
# <a href="https://colab.research.google.com/github/ViRoTex/Exercises-Statistics-R-and-Python/blob/main/Tarea_9_Data_Frame_en_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea 9. Data Frames en Python
# Carga en Python el CSV llamado run.csv que encontrarás en el repositorio del curso.

# %% [markdown]
# # Pregunta 1
# Indica cuántos estudiantes formaron parte del estudio de deporte.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/run.csv")
df

# %%
df.shape[0] # 92 estudiantes formaron parte del estudio

# %% [markdown]
# # Pregunta 2
# Indica cuántos individuos son hombres y cuántos son mujeres.

# %%
df.loc[0][5]

# %%
H = df.loc[df['genero'] == 'H'] # para ver los hombres de la columna género
H

# %%
H.shape[0] # 57 hombres

# %%
M = df.loc[df['genero'] == 'M']
M

# %%
M.shape[0] # 35 mujeres

# %% [markdown]
# # Pregunta 3
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio y
# compara el valor de los que hacen ejercicio habitualmente y los que no. ¿Observas mucha diferencia?

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/run.csv')
df
# Out:
#     Unnamed: 0  pulso.antes  pulso.despues hace.deporte fuma genero  altura  \
# 0            1           48             54           no   si      H    68.0
# 1            2           54             56           no   si      H    69.0
# 2            3           54             50           no   no      H    69.0
# 3            4           58             70           si   no      H    72.0
# 4            5           58             58           no   no      H    66.0
# ..         ...          ...            ...          ...  ...    ...     ...
# 87          88           92             94           no   si      H    69.0
# 88          89           94             92           no   si      M    62.0
# 89          90           96            140           si   no      M    61.0
# 90          91           96            116           si   no      M    68.0
# 91          92          100            115           si   si      M    63.0
#
#     peso tipo.actividad
# 0    150           nula
# ...

# %%
# cambiamos los ptos de las columnas por barras bajas 
df.columns = ['indice','pulso_antes','pulso_despues','hace_deporte','fuma','genero' ,'altura','peso', 'tipo_actividad']
df
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  peso  \
# 0        1           48             54           no   si      H    68.0   150
# 1        2           54             56           no   si      H    69.0   145
# 2        3           54             50           no   no      H    69.0   160
# 3        4           58             70           si   no      H    72.0   145
# 4        5           58             58           no   no      H    66.0   135
# ..     ...          ...            ...          ...  ...    ...     ...   ...
# 87      88           92             94           no   si      H    69.0   150
# 88      89           94             92           no   si      M    62.0   131
# 89      90           96            140           si   no      M    61.0   140
# 90      91           96            116           si   no      M    68.0   116
# 91      92          100            115           si   si      M    63.0   121
#
#    tipo_actividad
# ...

# %%
# creamos una función que nos dé el %pulso medio
def porcent_var_pulso(x):
  x['%pulso_medio'] = (x['pulso_despues']- x['pulso_antes'])/ x['pulso_antes']
  return x

# %%
# aplicamos dicha función a la tabla creada para añadir una nueva columna con el resultado
df = df.apply(porcent_var_pulso, axis = 1).round(2)

# %%
# hay que agrupar según si hacen o no deporte

df = df.set_index('hace_deporte')
df
# Out:
#               indice  pulso_antes  pulso_despues fuma genero  altura  peso  \
# hace_deporte
# no                 1           48             54   si      H    68.0   150
# no                 2           54             56   si      H    69.0   145
# no                 3           54             50   no      H    69.0   160
# si                 4           58             70   no      H    72.0   145
# no                 5           58             58   no      H    66.0   135
# ...              ...          ...            ...  ...    ...     ...   ...
# no                88           92             94   si      H    69.0   150
# no                89           94             92   si      M    62.0   131
# si                90           96            140   no      M    61.0   140
# si                91           96            116   no      M    68.0   116
# si                92          100            115   si      M    63.0   121
#
#              tipo_actividad  %pulso_medio
# ...

# %%
#vamos a hacer otra función con la media de los que hace deporte con los que no

df.groupby('hace_deporte').aggregate([np.mean]).round(2)
# Out:
#              indice pulso_antes pulso_despues altura    peso %pulso_medio
#                mean        mean          mean   mean    mean         mean
# hace_deporte
# no            47.02       72.42         72.32  68.07  141.12         0.00
# si            45.66       73.60         92.51  69.78  151.71         0.26

# %% [markdown]
# # Pregunta 4
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio para
# los estudiantes que hacen ejercicio habitualmente y compara el valor de los hombres con el de las mujeres.
# ¿Observas mucha diferencia?

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/run.csv')
df
# Out:
#     Unnamed: 0  pulso.antes  pulso.despues hace.deporte fuma genero  altura  \
# 0            1           48             54           no   si      H    68.0
# 1            2           54             56           no   si      H    69.0
# 2            3           54             50           no   no      H    69.0
# 3            4           58             70           si   no      H    72.0
# 4            5           58             58           no   no      H    66.0
# ..         ...          ...            ...          ...  ...    ...     ...
# 87          88           92             94           no   si      H    69.0
# 88          89           94             92           no   si      M    62.0
# 89          90           96            140           si   no      M    61.0
# 90          91           96            116           si   no      M    68.0
# 91          92          100            115           si   si      M    63.0
#
#     peso tipo.actividad
# 0    150           nula
# ...

# %%
#cambiamos los ptos de las columnas por barras bajas 
df.columns = ['indice','pulso_antes','pulso_despues','hace_deporte','fuma','genero' ,'altura','peso', 'tipo_actividad']
df
# quiero poner el género como índice
#df = df.set_index('genero')
#df
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  peso  \
# 0        1           48             54           no   si      H    68.0   150
# 1        2           54             56           no   si      H    69.0   145
# 2        3           54             50           no   no      H    69.0   160
# 3        4           58             70           si   no      H    72.0   145
# 4        5           58             58           no   no      H    66.0   135
# ..     ...          ...            ...          ...  ...    ...     ...   ...
# 87      88           92             94           no   si      H    69.0   150
# 88      89           94             92           no   si      M    62.0   131
# 89      90           96            140           si   no      M    61.0   140
# 90      91           96            116           si   no      M    68.0   116
# 91      92          100            115           si   si      M    63.0   121
#
#    tipo_actividad
# ...

# %%
#queremos eliminar los que no hacen deporte de la tabla 
df_depor = df["hace_deporte"] == "si" #es un filtro
df_depor = df.where(df_depor, inplace = True)
df
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  \
# 0      NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 1      NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 2      NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 3      4.0         58.0           70.0           si   no      H    72.0
# 4      NaN          NaN            NaN          NaN  NaN    NaN     NaN
# ..     ...          ...            ...          ...  ...    ...     ...
# 87     NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 88     NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 89    90.0         96.0          140.0           si   no      M    61.0
# 90    91.0         96.0          116.0           si   no      M    68.0
# 91    92.0        100.0          115.0           si   si      M    63.0
#
#      peso tipo_actividad
# 0     NaN            NaN
# 1     NaN            NaN
# ...

# %%
# quitamos los nan de 3 formas

# cambiando o modificando nuestro df
#df.dropna(inplace=True)
#df

#guardamos el df modificado en una nueva variable
dfSi = df.dropna()
dfSi


#Keep the DataFrame with valid entries in the same variable.
#mantiene el df tal cual, nos muestra una copia
#df.dropna()
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  \
# 3      4.0         58.0           70.0           si   no      H   72.00
# 6      7.0         60.0           76.0           si   no      H   71.00
# 11    12.0         62.0           76.0           si   si      H   73.50
# 12    13.0         62.0           75.0           si   no      H   72.00
# 13    14.0         62.0           58.0           si   no      H   72.00
# 14    15.0         62.0          100.0           si   no      M   66.00
# 15    16.0         62.0           98.0           si   si      M   62.75
# 20    21.0         64.0           88.0           si   no      H   66.00
# 21    22.0         64.0           80.0           si   no      H   69.00
# 24    25.0         66.0           78.0           si   si      H   73.00
# 25    26.0         66.0           82.0           si   si      H   69.00
# 26    27.0         66.0          102.0           si   no      H   70.00
# ...

# %%
# creamos una función que nos dé el %pulso medio
def porcent_var_pulso(x):
  x['%pulso_medio'] = (x['pulso_despues']- x['pulso_antes'])/ x['pulso_antes']
  return x

# %%
#aplicamos dicha función a la tabla creada para añadir una nueva columna con el resultado
dfSi=dfSi.apply(porcent_var_pulso, axis = 1).round(2)

# %%
# hay que agrupar según el género
#dfSi.groupby('genero').apply(porcent_var_pulso).round(2)
#dfSi.groupby('%pulso_medio').aggregate(np.mean).round(2)
dfSi = dfSi.set_index('genero')
dfSi
#df1.groupby('genero').apply(porcent_var_pulso).round(2)
#df1
# Out:
#         indice  pulso_antes  pulso_despues hace_deporte fuma  altura   peso  \
# genero
# H          4.0         58.0           70.0           si   no   72.00  145.0
# H          7.0         60.0           76.0           si   no   71.00  170.0
# H         12.0         62.0           76.0           si   si   73.50  160.0
# H         13.0         62.0           75.0           si   no   72.00  195.0
# H         14.0         62.0           58.0           si   no   72.00  175.0
# M         15.0         62.0          100.0           si   no   66.00  120.0
# M         16.0         62.0           98.0           si   si   62.75  112.0
# H         21.0         64.0           88.0           si   no   66.00  140.0
# H         22.0         64.0           80.0           si   no   69.00  155.0
# H         25.0         66.0           78.0           si   si   73.00  190.0
# H         26.0         66.0           82.0           si   si   69.00  175.0
# ...

# %%
#vamos a hacer otra función con la media del %pulso de H y el %pulso de M
#dfSi.apply()
dfSi.groupby('genero').aggregate([np.mean]).round(2)
# Out:
#        indice pulso_antes pulso_despues altura    peso %pulso_medio
#          mean        mean          mean   mean    mean         mean
# genero
# H       38.08       70.25         83.21  71.23  162.00         0.19
# M       62.18       80.91        112.82  66.61  129.27         0.42

# %% [markdown]
# # Ahora con los que no hacen deporte y comparar fumadores con no fumadores
# # Pregunta 5
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio para los
# estudiantes que no hacen ejercicio habitualmente y compara el valor de los fumadores con los no fumadores.
# ¿Observas mucha diferencia?

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/run.csv')
df
# Out:
#     Unnamed: 0  pulso.antes  pulso.despues hace.deporte fuma genero  altura  \
# 0            1           48             54           no   si      H    68.0
# 1            2           54             56           no   si      H    69.0
# 2            3           54             50           no   no      H    69.0
# 3            4           58             70           si   no      H    72.0
# 4            5           58             58           no   no      H    66.0
# ..         ...          ...            ...          ...  ...    ...     ...
# 87          88           92             94           no   si      H    69.0
# 88          89           94             92           no   si      M    62.0
# 89          90           96            140           si   no      M    61.0
# 90          91           96            116           si   no      M    68.0
# 91          92          100            115           si   si      M    63.0
#
#     peso tipo.actividad
# 0    150           nula
# ...

# %%
#cambiamos los ptos de las columnas por barras bajas 
df.columns = ['indice','pulso_antes','pulso_despues','hace_deporte','fuma','genero' ,'altura','peso', 'tipo_actividad']
df
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  peso  \
# 0        1           48             54           no   si      H    68.0   150
# 1        2           54             56           no   si      H    69.0   145
# 2        3           54             50           no   no      H    69.0   160
# 3        4           58             70           si   no      H    72.0   145
# 4        5           58             58           no   no      H    66.0   135
# ..     ...          ...            ...          ...  ...    ...     ...   ...
# 87      88           92             94           no   si      H    69.0   150
# 88      89           94             92           no   si      M    62.0   131
# 89      90           96            140           si   no      M    61.0   140
# 90      91           96            116           si   no      M    68.0   116
# 91      92          100            115           si   si      M    63.0   121
#
#    tipo_actividad
# ...

# %%
#queremos eliminar los que si hacen deporte de la tabla
df_vagos = df["hace_deporte"] == "no" #es un filtro
df_vagos = df.where(df_vagos, inplace = True)
df
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  \
# 0      1.0         48.0           54.0           no   si      H    68.0
# 1      2.0         54.0           56.0           no   si      H    69.0
# 2      3.0         54.0           50.0           no   no      H    69.0
# 3      NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 4      5.0         58.0           58.0           no   no      H    66.0
# ..     ...          ...            ...          ...  ...    ...     ...
# 87    88.0         92.0           94.0           no   si      H    69.0
# 88    89.0         94.0           92.0           no   si      M    62.0
# 89     NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 90     NaN          NaN            NaN          NaN  NaN    NaN     NaN
# 91     NaN          NaN            NaN          NaN  NaN    NaN     NaN
#
#      peso tipo_actividad
# 0   150.0           nula
# 1   145.0       moderada
# ...

# %%
# quitamos los nan 
#guardamos el df modificado en una nueva variable
dfNo = df.dropna()
dfNo
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  \
# 0      1.0         48.0           54.0           no   si      H   68.00
# 1      2.0         54.0           56.0           no   si      H   69.00
# 2      3.0         54.0           50.0           no   no      H   69.00
# 4      5.0         58.0           58.0           no   no      H   66.00
# 5      6.0         58.0           56.0           no   no      M   67.00
# 7      8.0         60.0           62.0           no   no      H   71.00
# 8      9.0         60.0           70.0           no   si      H   71.50
# 9     10.0         60.0           66.0           no   no      M   62.00
# 10    11.0         61.0           70.0           no   no      M   65.50
# 16    17.0         62.0           62.0           no   no      H   74.00
# 17    18.0         62.0           66.0           no   no      H   70.00
# 18    19.0         62.0           68.0           no   si      H   73.00
# ...

# %%
# creamos una función que nos dé el %pulso medio
def porcent_var_pulso(x):
  x['%pulso_medio'] = (x['pulso_despues']- x['pulso_antes'])/ x['pulso_antes']
  return x

# %%
#aplicamos dicha función a la tabla creada para añadir una nueva columna con el resultado
dfNo=dfNo.apply(porcent_var_pulso, axis = 1).round(2)

# %%
# hay que agrupar según el género

dfNo = dfNo.set_index('fuma')
dfNo
# Out:
#       indice  pulso_antes  pulso_despues hace_deporte genero  altura   peso  \
# fuma
# si       1.0         48.0           54.0           no      H   68.00  150.0
# si       2.0         54.0           56.0           no      H   69.00  145.0
# no       3.0         54.0           50.0           no      H   69.00  160.0
# no       5.0         58.0           58.0           no      H   66.00  135.0
# no       6.0         58.0           56.0           no      M   67.00  125.0
# no       8.0         60.0           62.0           no      H   71.00  155.0
# si       9.0         60.0           70.0           no      H   71.50  164.0
# no      10.0         60.0           66.0           no      M   62.00  120.0
# no      11.0         61.0           70.0           no      M   65.50  120.0
# no      17.0         62.0           62.0           no      H   74.00  190.0
# no      18.0         62.0           66.0           no      H   70.00  155.0
# ...

# %%
#vamos a hacer otra función con la media del %pulso de H y el %pulso de M

dfNo.groupby('fuma').aggregate([np.mean]).round(2)
# Out:
#      indice pulso_antes pulso_despues altura    peso %pulso_medio
#        mean        mean          mean   mean    mean         mean
# fuma
# no    45.51       71.71         71.51  68.08  138.20        -0.00
# si    50.88       74.25         74.38  68.03  148.62         0.01

# %% [markdown]
# # Ahora poner el %pulso según la intensidad de la actividad que realicen
# # Pregunta 6
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio de
# todos los estudiantes según el tipo de actividad física que realizan. ¿Observas alguna diferencia?

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/run.csv')
df
# Out:
#     Unnamed: 0  pulso.antes  pulso.despues hace.deporte fuma genero  altura  \
# 0            1           48             54           no   si      H    68.0
# 1            2           54             56           no   si      H    69.0
# 2            3           54             50           no   no      H    69.0
# 3            4           58             70           si   no      H    72.0
# 4            5           58             58           no   no      H    66.0
# ..         ...          ...            ...          ...  ...    ...     ...
# 87          88           92             94           no   si      H    69.0
# 88          89           94             92           no   si      M    62.0
# 89          90           96            140           si   no      M    61.0
# 90          91           96            116           si   no      M    68.0
# 91          92          100            115           si   si      M    63.0
#
#     peso tipo.actividad
# 0    150           nula
# ...

# %%
#cambiamos los ptos de las columnas por barras bajas 
df.columns = ['indice','pulso_antes','pulso_despues','hace_deporte','fuma','genero' ,'altura','peso', 'tipo_actividad']
df
# Out:
#     indice  pulso_antes  pulso_despues hace_deporte fuma genero  altura  peso  \
# 0        1           48             54           no   si      H    68.0   150
# 1        2           54             56           no   si      H    69.0   145
# 2        3           54             50           no   no      H    69.0   160
# 3        4           58             70           si   no      H    72.0   145
# 4        5           58             58           no   no      H    66.0   135
# ..     ...          ...            ...          ...  ...    ...     ...   ...
# 87      88           92             94           no   si      H    69.0   150
# 88      89           94             92           no   si      M    62.0   131
# 89      90           96            140           si   no      M    61.0   140
# 90      91           96            116           si   no      M    68.0   116
# 91      92          100            115           si   si      M    63.0   121
#
#    tipo_actividad
# ...

# %%
# creamos una función que nos dé el %pulso medio
def porcent_var_pulso(x):
  x['%pulso_medio'] = (x['pulso_despues']- x['pulso_antes'])/ x['pulso_antes']
  return x

# %%
#aplicamos dicha función a la tabla creada para añadir una nueva columna con el resultado
df = df.apply(porcent_var_pulso, axis = 1).round(2)

# %%
# hay que agrupar según el grado de actividad

df = df.set_index('tipo_actividad')
df
# Out:
#                 indice  pulso_antes  pulso_despues hace_deporte fuma genero  \
# tipo_actividad
# nula                 1           48             54           no   si      H
# moderada             2           54             56           no   si      H
# moderada             3           54             50           no   no      H
# moderada             4           58             70           si   no      H
# intensa              5           58             58           no   no      H
# ...                ...          ...            ...          ...  ...    ...
# moderada            88           92             94           no   si      H
# moderada            89           94             92           no   si      M
# moderada            90           96            140           si   no      M
# moderada            91           96            116           si   no      M
# moderada            92          100            115           si   si      M
#
# ...

# %%
#vamos a hacer otra función con la media del %pulso de H y el %pulso de M

df.groupby('tipo_actividad').aggregate([np.mean]).round(2)
# Out:
#                indice pulso_antes pulso_despues altura    peso %pulso_medio
#                  mean        mean          mean   mean    mean         mean
# tipo_actividad
# intensa         43.29       71.57         72.19  69.57  147.29         0.01
# moderada        45.93       72.74         82.79  68.38  143.75         0.14
# nula             1.00       48.00         54.00  68.00  150.00         0.12
# suave           62.89       79.56         82.22  69.11  149.11         0.04
